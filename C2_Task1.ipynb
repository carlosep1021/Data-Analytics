# %% [markdown]
# # Task 1: Get Started with Data Science

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from pandas_profiling import ProfileReport

# %% [markdown]
# Installing Python has been pretty straight forward following the instructions given. However, some of the libraries required a lot of troubleshooting. For instance, pandas_profiling. It requires a lot of investigation to get it working correctly.

# %% [markdown]
# ## Reading Dataset using Pandas

# %%
credit=pd.read_csv('default of credit card clients.csv', header=1)

# %% [markdown]
# This is the .csv file used for Course 2 - Task 1.

# %% [markdown]
# ## Analysis Data

# %%
credit.head()
# Out:
#    ID  LIMIT_BAL     SEX   EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 0   1      20000  female  university         1   24      2      2     -1
# 1   2     120000  female  university         2   26     -1      2      0
# 2   3      90000  female  university         2   34      0      0      0
# 3   4      50000  female  university         1   37      0      0      0
# 4   5      50000    male  university         1   57     -1      0     -1
#
#    PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0     -1  ...          0          0          0         0       689         0
# 1      0  ...       3272       3455       3261         0      1000      1000
# 2      0  ...      14331      14948      15549      1518      1500      1000
# 3      0  ...      28314      28959      29547      2000      2019      1200
# 4      0  ...      20940      19146      19131      2000     36681     10000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# ...

# %%
credit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          30000 non-null  int64
#  1   LIMIT_BAL                   30000 non-null  int64
#  2   SEX                         30000 non-null  object
#  3   EDUCATION                   30000 non-null  object
#  4   MARRIAGE                    30000 non-null  int64
#  5   AGE                         30000 non-null  int64
#  6   PAY_0                       30000 non-null  int64
#  7   PAY_2                       30000 non-null  int64
#  8   PAY_3                       30000 non-null  int64
#  9   PAY_4                       30000 non-null  int64
#  10  PAY_5                       30000 non-null  int64
#  11  PAY_6                       30000 non-null  int64
#  12  BILL_AMT1                   30000 non-null  int64
# ...

# %%
credit.describe()
# Out:
#                  ID       LIMIT_BAL      MARRIAGE           AGE         PAY_0  \
# count  30000.000000    30000.000000  30000.000000  30000.000000  30000.000000
# mean   15000.500000   167484.322667      1.551867     35.485500     -0.016700
# std     8660.398374   129747.661567      0.521970      9.217904      1.123802
# min        1.000000    10000.000000      0.000000     21.000000     -2.000000
# 25%     7500.750000    50000.000000      1.000000     28.000000     -1.000000
# 50%    15000.500000   140000.000000      2.000000     34.000000      0.000000
# 75%    22500.250000   240000.000000      2.000000     41.000000      0.000000
# max    30000.000000  1000000.000000      3.000000     79.000000      8.000000
#
#               PAY_2         PAY_3         PAY_4         PAY_5         PAY_6  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      -0.133767     -0.166200     -0.220667     -0.266200     -0.291100
# ...

# %%
# Create a report for all the variables in the data set with the title: Credit Profiling Report

# profile = credit.profile_report(title='Credit Profiling Report', html={'style':{'full_width':True}})

# %%
# Print the report in HTML file

# profile.to_file(output_file="Credit_report.html")

# %% [markdown]
# The profile_report helps enormously for initial insights about the data, and to check where something is wrong and need to be worked out.
#
# I created a separate file with the report (html file) and checked from the file all the potential issues with the data.

# %%
credit.drop_duplicates()
# Out:
#           ID  LIMIT_BAL     SEX    EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  \
# 0          1      20000  female   university         1   24      2      2
# 1          2     120000  female   university         2   26     -1      2
# 2          3      90000  female   university         2   34      0      0
# 3          4      50000  female   university         1   37      0      0
# 4          5      50000    male   university         1   57     -1      0
# ...      ...        ...     ...          ...       ...  ...    ...    ...
# 29995  29996     220000    male  high school         1   39      0      0
# 29996  29997     150000    male  high school         2   43     -1     -1
# 29997  29998      30000    male   university         2   37      4      3
# 29998  29999      80000    male  high school         1   41      1     -1
# 29999  30000      50000    male   university         1   46      0      0
#
#        PAY_3  PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# ...

# %%
print(credit.isnull().sum())
# Out:
# ID                            0
# LIMIT_BAL                     0
# SEX                           0
# EDUCATION                     0
# MARRIAGE                      0
# AGE                           0
# PAY_0                         0
# PAY_2                         0
# PAY_3                         0
# PAY_4                         0
# PAY_5                         0
# PAY_6                         0
# BILL_AMT1                     0
# BILL_AMT2                     0
# BILL_AMT3                     0
# BILL_AMT4                     0
# BILL_AMT5                     0
# BILL_AMT6                     0
# PAY_AMT1                      0
# PAY_AMT2                      0
# PAY_AMT3                      0
# PAY_AMT4                      0
# PAY_AMT5                      0
# PAY_AMT6                      0
# default payment next month    0
# dtype: int64

# %% [markdown]
# A lot of SyntaxError writing the code which one uppercase instead of lowercase or a missing parenthesis could create and error.
#
# The way to overcome these type of errors as well as other such as ValueError, AttributeError, etcetera is with google. I copied the full line in the prompt line, and I have found somebody posting similar or even the same error and it had been solved.
#
# Finally, the best way to learn is “jumping to the water” and clear the errors when they come up. Right now, I feel more confident in finding ways to fix an error while I am running the code.
